# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sodapy import Socrata

# %%
client = Socrata("data.cdc.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("n8mc-b4w4", limit=2000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#      case_month res_state state_fips_code res_county county_fips_code  \
# 0       2020-08        NA              NA         NA               NA
# 1       2020-08        NA              NA         NA               NA
# 2       2020-08        NA              NA         NA               NA
# 3       2020-08        NA              NA         NA               NA
# 4       2020-08        NA              NA         NA               NA
# ...         ...       ...             ...        ...              ...
# 1995    2020-04        MN              27         NA               NA
# 1996    2020-04        MN              27         NA               NA
# 1997    2020-04        MN              27         NA               NA
# 1998    2020-04        MN              27         NA               NA
# 1999    2020-04        MN              27         NA               NA
#
#      age_group sex race ethnicity  process exposure_yn  \
# 0           NA  NA   NA        NA  Missing     Missing
# 1           NA  NA   NA        NA  Missing     Missing
# 2           NA  NA   NA        NA  Missing     Missing
# 3           NA  NA   NA        NA  Missing     Missing
# 4           NA  NA   NA        NA  Missing     Missing
# ...        ...  ..  ...       ...      ...         ...
# 1995        NA  NA   NA        NA  Missing         Yes
# 1996        NA  NA   NA        NA  Missing         Yes
# 1997        NA  NA   NA        NA  Missing     Missing
# 1998        NA  NA   NA        NA  Missing         Yes
# 1999        NA  NA   NA        NA  Missing         Yes
#
#                  current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 1                 Probable Case        Missing  Missing  Missing  Missing
# 2     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 3     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# ...                         ...            ...      ...      ...      ...
# 1995  Laboratory-confirmed case    Symptomatic      Yes      Yes       No
# 1996  Laboratory-confirmed case    Symptomatic  Missing  Missing       No
# 1997  Laboratory-confirmed case    Symptomatic       No  Missing       No
# 1998  Laboratory-confirmed case    Symptomatic  Missing  Missing       No
# 1999  Laboratory-confirmed case    Symptomatic       No  Missing       No
#
#      case_positive_specimen underlying_conditions_yn case_onset_interval
# 0                       NaN                      NaN                 NaN
# 1                       NaN                      NaN                 NaN
# 2                       NaN                      NaN                 NaN
# 3                       0.0                      NaN                 NaN
# 4                       NaN                      NaN                 NaN
# ...                     ...                      ...                 ...
# 1995                    0.0                      Yes                 0.0
# 1996                    1.0                      Yes                 0.0
# 1997                    1.0                      Yes                 0.0
# 1998                    1.0                      NaN                 0.0
# 1999                    0.0                      NaN                 0.0
#
# [2000 rows x 19 columns]
